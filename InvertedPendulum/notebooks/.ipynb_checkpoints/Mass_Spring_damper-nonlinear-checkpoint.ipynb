# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# Fake nonlinear MSD system
#
# $ m\ddot{x}(t) = -kx^2(t) - d\dot{x}(t) + F $
#
# where
# - x(t) = position at time t
# - m = mass
# - d = damper constant
# - k = spring constant
# - $ \tau $ = time period
#
# $ \dot{x}(t+\tau) = (1-\frac{d}{m}\tau)\dot{x}(t) + (\frac{-k}{m}\tau)x(t) + \frac{1}{m}\tau F(t) $
#
# $ x(t+\tau) = \dot{x}(t)\tau + x(t) $
#
# $ \vec{x}(t+\tau) = A\vec{x}(t) + B\vec{F}(t) $

# %%
tau = 1/100
freq = 1/tau

# %% [markdown]
# $ \vec{F} $ will be a frequency sweep

# %%
begin_time = 0
end_time = 100
samples = int((end_time-begin_time)*freq)

time = np.linspace(begin_time,end_time,samples,endpoint=False)

# %%
end_freq = 1
magnitude = 1

F = magnitude*np.sin((end_freq*time/end_time)*2*np.pi*time)
#F = np.zeros_like(time)

# %%
plt.figure(figsize=(25,2))
plt.plot(time,F)
plt.ylabel("Force")
plt.xlabel("time")
plt.show()

# %%
class System:
    def __init__(self, A, B, initial_state = None):
        self.A = A
        self.B = B
        self.dim = A.shape[0]
        
        if np.any(initial_state == None):
            self.state = np.random.randn(self.dim)
        else:
            self.state = initial_state
            
    def step(self,force):
        next_state = self.A @ self.state + self.B * force**2
        self.state = next_state
        
        return self.state

# %%
m = 1
d = 0.1
k = 3

A = np.array([[1-d/m*tau,-k/m*tau],
             [tau,1]])

B = np.array([tau/m,0])

# %%
TESTS = 100
ITERATION = len(F)

test_msd = []
test_states = []

for test in range(TESTS):
    msd = System(A,B)
    test_msd.append(msd)

    states = [msd.state]

    for i in range(ITERATION):
        states.append(msd.step(F[i]))
        
    test_states.append(states)

# %%
print(states[100],F[100])
print(states[101],F[101])
# Out:
# [-1.49543481 -0.01113322] 0.06279051952931337
# [-1.49356595 -0.02608757] 0.06405089728196535

# %%
states = np.array(states)

plt.figure(figsize=(25,5))
plt.plot(range(ITERATION),states[1:,1],label="Position")
plt.plot(range(ITERATION),states[1:,0],label="Velocity")
plt.plot(range(ITERATION),F[:ITERATION],label="Force",alpha=0.5)
plt.legend()
plt.show()

# %%
test_states = np.array(test_states)
np.save(f'data_msd/test_states-{m}-{k}-{d}-nonlinear.npy',test_states)

# %%
np.save(f'data_msd/states{m}-{k}-{d}-nonlinear.npy', states)
np.save(f'data_msd/forces{m}-{k}-{d}-nonlinear.npy', F)

# %%
msd_test = System(A,B,initial_state = np.array([1,-1]))

# %%
ITERATION = 200
time = np.linspace(0,ITERATION*tau,ITERATION,endpoint=False)
F_test = np.cos(time)

# %%
ITERATION = len(F_test)

states_test = [msd_test.state]

for i in range(ITERATION):
    states_test.append(msd_test.step(F_test[i]))

# %%
states_test = np.array(states_test)

plt.figure(figsize=(25,5))
plt.plot(time,states_test[1:,0],label="Velocity")
plt.plot(time,states_test[1:,1],label="Position")
plt.plot(time,F_test,label = "Force",alpha=0.5)
plt.ylim([-3,3])
plt.legend()
plt.show()
